# %% [markdown]
# <a href="https://colab.research.google.com/github/Anderstitch56/Pesca-Comabte/blob/main/PescaCombabte.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import random
import os

#conts
quantidade = 0
escolha = 1
valor = 0
valor2 = 0
dado = 0
decisao = 4
decisao2 = 4
cont = 0
resultpeixe = 0
vida = 20
acao2 = 4
acao3 = 4
contacao3 = 0
contpesca = 1
moeda = 0
i = 0
contcilco = 0

#radom
dicas = ["Em dias de frio os peixes descem para o fundo do rio para se aquecerem \n use chumbadas mais pesadas para pega-los", "Se for pescar a noite não esqueça seu lampião", "Fique de olho na boia da vara para os peixes não comerem a isca \nsem que você perceba"]
peixes = ["Tucunaré", "Tilapia", "Lambari", "Pacu", "Piranha", "Tambaqui", "Corvina"]
peixesraros = ["Pirara", "Dourado", "Peixe cahorro", "Aruanã","Pintado" ]
peixeslendarios = ["Lambari Dourado", "Dourado Gigante","Tilapia Arco-íris"]
itensdepesca = ["Linha de pescar nova", "Um dedo humano falso...", "Uma bota de couro velha", "Um capim enroscado... (._.)Z", "Uma meia colorida","Um chapéu"]

peixespegos = []
itenspegos = []
peixesnotanque = []

#def de pesca
def pescaria():
  global contpesca
  global resultpeixe
  global valor
  global contciclo

  print("*jogando anzol na água*")
  time.sleep(3)
  print("*água se movimenta*")
  time.sleep(3)
  print ("*boia da vara afunda*")
  contpesca = 1
  contciclo = 0
  while contpesca == 1:
    pesca = str (input("PUXE SUA VARA AGORA: "))
    if pesca == "puxar":
      mostralinha()
      d1()
      time.sleep(1)
      contpesca = 2
    if pesca != "puxar":
      print("Puxa mais uma vez")
      print("")
      contciclo += 1

      if contciclo == 2:
        contpesca = 2
        valor = 2
        cont

  if valor <= 2:
    print("O peixe escapou...")
    print("")

  if valor == 4 or valor == 3:
    print("Ele ainda está na linha")
    print("Ele luta bravamente contra a linha e...")
    possibilidade2 = random.randint(1,6)
    time.sleep(2)
    print()
    if possibilidade2 <= 3:
      print("Você consegue retirar ele da água e pega um: ")
      peixadas()
      
    else:
      print("Ele escapou...")
     
  if valor >= 5:
    print("*tirando o peixe da água*")
    time.sleep(3)
    print ("Você pescou um(a): ")
    peixadas()
    print("")
#def jogar peixes no tanque
def jogapeixenotanque():
  global peixespegos
  global peixesnotanque
  global acao4
  print("")
  acao4 = 3
  while acao4 >= 3:
    acao4 = int (input("Deseja jogar o peixe no tanque? \nSim (1)   Não (2) \n-> "))
  if acao4 == 1:
    print("*Jogando peixes no tanque*")
    peixesnotanque = peixespegos[:]
    time.sleep(3)
    print("Peixes no seu tanque atualmente: ")
    for v in peixesnotanque:
      print(f"{v}")
    acao4 = 1
    if acao4 == 2:
      print("Beleza, vamos guarda-los na sua bolsa de pesca")   


#def de mostar a linha
def mostralinha():
    print("_"*28)
    print("")

#Def de dados
def dados():
  global valor
  print("Escolha o dado a ser usado: ")
  dado = int (input("D6 (1) \nD20 (2) \nD100 (3) \n-> "))
  if dado == 1:
    valor = random.randint(1,6)
    print("os resultado dos dados deram : ", valor)
  elif dado == 2:
    print("o resultado dos dados deram : ", random.randint(1,20))
  elif dado == 3:
    print("o resultado dos dados deram : ", random.randint(1,100))
#def d1
def d1():
  global valor
  print("Vamos rolar os dados e ver os resultados")
  time.sleep(1)
  valor = random.randint(1,6)
  print("os resultado dos dados deram : ", valor)

#def d20
def d20(): 
  global valor
  print("Vamos rolar os dados e ver os resultados")
  time.sleep(1)
  valor = random.randint(1,20)
  print("os resultado dos dados deram : ", valor)
#def d100
def d100():
  global valor
  print("Vamos rolar os dados e ver os resultados")
  time.sleep(1)
  valor = random.randint(1,100)
  print("os resultado dos dados deram : ", valor)

#def d100 para pescar
def peixadas ():
  global itenspegos
  global peixespegos
  global moeda
  global valor2
  global resultpeixe
  valor2 = random.randint(1,100)

  if valor2 <= 50:
    peixespegos.insert(0,random.choice(peixes))
    print(peixespegos[0])
    print("Raridade: Comum \nMoedas: +5")
    moeda += 5
    resultpeixe += 1

  if valor2 >= 51 and valor2 <= 79:
    peixespegos.insert(0,random.choice(peixesraros))
    print(peixespegos[0])
    print("Raridade: Incomum \nMoedas: +15")
    moeda += 15
    resultpeixe += 1

  if valor2 >= 80 and valor2 <= 94:
    itenspegos.insert(0,random.choice(itensdepesca))
    print(itenspegos[0])
    print("Raridade: ??? depende do item \nMoedas: 0")

  if valor2 >= 95:
    peixespegos.insert(0,random.choice(peixeslendarios))
    print(peixespegos[0])
    print("Raridade: Lendario \nMoedas: +25")
    moeda += 25
    resultpeixe += 1

     


print("RPG Fishing in the Combate")
print("Olá jovem pescador como você está? \nSe você está perdido Deixe-me te guiar nesse mundo cheio peixes e aventuras ")
nome = str (input("Qual é seu nome meu querido pescador ?: \n-> "))
mostralinha()
print("É um prazer te conhecer ", nome,"\nMe chamo narrador")
time.sleep(2)
print("Chega de formalidades, temos peixes a serem pegos e uma fazenda pra cuidar")
time.sleep(2)

while decisao >= 4:
  print("Oque você quer fazer primeiro ? ")
  time.sleep(1)
  decisao = int (input("Pescar no seu tanque de peixes (1) \nPescar no rio (2) \nDormir na rede da varanda da sua casa (3) \n-> "))
  cont += 1
  if cont == 5:
    print("Vamos lá nós temos um dia cheio pela frente, escolhe logo alguma coisa")

print("Certo vamos lá então ")

if decisao == 1:
  mostralinha()
  print("xiii você tem um tanque com água... mas não tem peixe \nvamos a procura de alguns no rio")
  time.sleep (2)
  decisao = 2

if decisao == 3:
  print("Essa rede parece confortavel ")
  time.sleep(1)
  print("Você se deita pra dormir ")
  print ("Você ta sem sono e vai pescar pois seu sangue de pescador ferve só de saber que os lambaris o esperam no rio")
  decisao = 2
  time.sleep(2)

if decisao == 2:
  mostralinha()
  print("Partiu pescar no rio ")
  print("*caminhando até o rio*")
  print("*DICA DO DIA: ", random.choice(dicas))
  time.sleep(6)
  mostralinha()

print("Chegamos no rio")
print("Nossa hoje o sol ta a pino e os peixes fervorecentes na água vamos pescar")
acao = int (input("Jogar o anzol (1) \nMergulhar (2) \nAdmirar o rio (3) \n-> "))

if acao == 3:
  mostralinha()
  print ("*admirando o rio*")
  time.sleep (2)
  print("Agora que você admirou o rio percebe que do outro lado da margem tem outra pessoa ")
  print("É o marcinho Tucunaré, seu vizinho, ele te olha com um olhar de canto... \nBora pescar né")
  acao = 1
  time.sleep(3)

if acao == 2:
  mostralinha()
  print("*pulando no rio*")
  time.sleep (2)
  print ("a água está muito turva e escura... mas da pra sentir muitos peixes passando por baixo dos pés")
  print ("partiu de pescar")
  acao = 1
  time.sleep(3)

if acao == 1:
  mostralinha()
  print("Digite (puxar) para pescar")
  print("")

  while escolha == 1:
      pescaria()
      print("Deseja pescar mais uma vez? ")
      escolha = int (input("Sim (1)   Não (2) \n-> " ))
      mostralinha()

      if escolha == 2:
        mostralinha()
        print("Você para e descansa... ")
        quantidade = int(input("Deseja ver a quantidade de peixes pegos moedas adquiridas ?\nSim (1)  Não (2)\n->"))
        mostralinha()
      if quantidade == 1:
        print("Quantidade de peixes pegos: ", resultpeixe,"\nQuantidade de moedas: ", moeda)
        time.sleep(1)
        print("vamos fazer oque agora? ")
        print("")
      if quantidade == 2:
        mostralinha()
        print ("Agora que paramos um pouco oque deseja fazer?")
        print("")
        time.sleep(3)
while acao2 >= 4:
  acao2 = int (input("Embora pra casa por os peixes no tanque (1) \nPescar denovo (2) \nMergulhar (3) \n-> "))
if acao2 == 1:
  mostralinha()
  print("Partiu guardar esses peixes no tanque da sua casa")
  
if acao2 == 2:
  escolha = 1
  while escolha == 1:
      mostralinha()
      pescaria()
      print("Deseja pescar mais uma vez? ")
      escolha = int (input("Sim (1)   Não (2) \n-> " ))
if escolha == 2:
  print("Vamos soltar esses peixes lá na sua casa")

if acao2 == 3:
  mostralinha()
  print("*mergulhando*")
  time.sleep(1)
  print("Você sentiu um peixe passar por perto de você...")
  pegapeixe = int (input("Você quer tentar pega-lo? \nSim(1)     Não(2) \n->  "))
  if pegapeixe == 1:
    d1()
    if valor == 3 or valor == 4:
      possibilidade2 = random.randint(1,6)
      time.sleep(2)
      print()
      if possibilidade2 >= 4 :
        valor = 5
      else:
        valor = 2

    if valor <= 2:
      print("o peixe escapou... parecia grande ")

    if valor >=5:
      print("você consegue agarra-lo")
      print("Espera um momento... esse peixe é um...")
      time.sleep(3)
      print("VOCÊ PEGOU UM JACARÉ AAAAAAAAAHHHHH")
      mostralinha()
      print("um combate se inicia")
      print("")
      while acao3 >= 4:
        acao3 = int (input("Oque você vai fazer? \nLutar(1) \nDefender (2) \nFugir (3) \n->  "))
        print("")
        contacao3 += 1
        if contacao3 == 5:
          mostralinha()
          print("Escolheeee pelo amor de DEUS")
        if contacao3 == 10:
          mostralinha()
          print("Ja que você ta em choque e não sabe oque fazer ao lutar com um jacaré \nEu te ajudo, Você vai lutar com ele ")
          print("")
          acao3 = 1
      if acao3 == 2:
        mostralinha()
        d1()
        if valor <= 3:
          print("Sua defesa falha")
          time.sleep(3)
          print("ele ataca com uma mordida e tira: ")
          d1()
          print("ele tirou -", valor, " De vida sua")
          vida -= valor
          print("Você tem agora ", vida, " De vida")
          time.sleep(2)
          print("O jacaré vai embora... ")
          print("Você ta com um machucado, melhor ir embora pra cuidar dele ")
          print("*Saindo da água*")
          mostralinha()
        if valor >= 4:
          time.sleep(3)
          print("Você esquivou do ataque e o jacaré meteu o pé")
          print("Essa foi por um pouquinho nossa.... sério ")
          mostralinha()
      if acao3 == 3:
        possibilidade2 = random.randint(1,6)
        
        if possibilidade2 <= 3:
          time.sleep(3)
          mostralinha()
          print("Sua tentativa de fugir falhou...")
          print("O jacaré tenta contra ataca com uma mordida e tira: ")
          d1()
          print("ele tirou -", valor, " De vida sua")
          vida -= valor
          print("Você tem agora ", vida, " De vida")
          time.sleep(2)
          print("O jacaré vai embora... ")
          print("Você ta com um machucado, melhor ir embora pra cuidar dele ")
          print("*Saindo da água*")
          print("Vamos embora...")
          mostralinha()
        else:
          time.sleep(3)
          print("Você consegue fugir... Essa foi por pouco ")
          print("Melhor começar a pensar melhor antes de pegar qualquer coisa de baixo da ág...")
          time.sleep(3)
          print("*Alguma coisa passa por debaixo do seu pé *")
          print("Quer tentar pegar ???  : ) ")
          print("Mentira kskks, vamo embora descansar ")
          mostralinha()

      if acao3 == 1:
        mostralinha()
        golpes = int (input ("Qual o golpe você  vai dar no jacaré? \nUm soco (1) \nChutar (2) \nBater com um item (3) \n-> "))
        if golpes == 1:
          mostralinha()
          print("Você tenta dar um soco eeee....")
          d20()
          #luta com jacare
          if valor >= 10 or valor <= 14:
            time.sleep(2)
            print()
            possibilidade2 = random.randint(1,6)
            
            if possibilidade2 >= 4:
              valor = 15

            if possibilidade2 <= 3:
              valor = 5

          if valor <= 9:
            time.sleep(3)
            print("Seu coco não faz efeito e o jacaré te olha estranho...")
            print("ele contra ataca com uma mordida e tira: ")
            d1()
            print("ele tirou -", valor, " De vida sua")
            vida -= valor
            print("Você tem agora ", vida, " De vida")
            time.sleep(3)
            print("O jacaré vai embora... ")
            print("Você ta com um machucado, melhor ir embora pra cuidar dele ")
            print("*Saindo da água*")
            mostralinha()

          if valor >= 15:
            time.sleep(3)
            print("Você acerta o um soco de cruzado no olho do jacaré e ele foge... ")
            print("Essa foi por pouco em... oia, mais um pouco e tinha virado ifood de jacaré")
      if golpes == 2:
        possibilidade2 = random.randint(1,6)
        if possibilidade2 <= 3:
          print("Seu chute não faz efeito e o jacaré te olha estranho...")
          print("ele contra ataca com uma mordida e tira: ")
          d1()
          print("ele tirou -", valor, " De vida sua")
          vida -= valor
          print("Você tem agora ", vida, " De vida")
          time.sleep(3)
          print("O jacaré vai embora... ")
          print("Você ta com um machucado, melhor ir embora pra cuidar dele ")
          print("*Saindo da água*")
        else:
          print("Você consegue dar o chute e com os movimentos debaixos dágua")
          print("Você acaba se impurando pra longe dele e consegue fugir")
          print("Essa foi por um triz... mais um pouco e você virava um apelitivo de lacoste mano")

      if golpes == 3:
        print("itens a serem usados")
        itemescolhido = int (input("peixes (1) \n-> "))
        if itemescolhido == 1:
          print("Peixes disponiveis no seu inventário: ")
          for c, v in enumerate(peixespegos):
            print(f"Na posicão {c} está o peixe {v}")
          escolhaitem = int(input("Qual peixe você vai usar ? (Digite a posição dele) \n-> "))
          mostralinha()
          print("Você usou o peixe: ", peixespegos[escolhaitem])
          print("-1 peixe no invetário")
          del peixespegos[escolhaitem]
          resultpeixe -= 1
          print("Você joga o peixe pro jacaré")
          print("Ele come o peixe e se distrai")
          print("Você foge")
          print("Essa foi por um pouqinho kskks")
          print("Partiu soltar esses peixes no tanque da sua casa")

  if pegapeixe == 2:
    print("Belza, vamo embora então")

#fim do primeiro dia
mostralinha()
print("*Caminhando embora pra casa*")
time.sleep(3.5)
print("")
print("Dica do dia: ",random.choice(dicas))
time.sleep(6)
print("")
mostralinha()
print("Chegamos na sua casa")
print("")
print("Você agora tem: \nTotal de peixes pegos: ",resultpeixe," \nTipo depeixes pegos: ")
for v in peixespegos:
  print(f"{v}")
print("Quatidade de moedas: ", moeda," \nVida total: ",vida,"/20")
jogapeixenotanque()
# Out:
# RPG Fishing in the Combate
# Olá jovem pescador como você está?
# Se você está perdido Deixe-me te guiar nesse mundo cheio peixes e aventuras
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-4c352633663c> in <module>
#     188 print("RPG Fishing in the Combate")
#     189 print("Olá jovem pescador como você está? \nSe você está perdido Deixe-me te guiar nesse mundo cheio peixes e aventuras ")
# --> 190 nome = str (input("Qual é seu nome meu querido pescador ?: \n-> "))
#     191 mostralinha()
#     192 print("É um prazer te conhecer ", nome,"\nMe chamo narrador")
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# ...
